# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd
import os
import csv
import numpy as np

# %%
# load CSV
csvpath = os.path.join("Resources", "2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file

dataclean2_df = pd.read_csv(csvpath,dtype=object,)

dataclean2_df.head(10)
# Out:
#   Age AttendedBootcamp BootcampFinish BootcampFullJobAfter BootcampLoanYesNo  \
# 0  28                0            NaN                  NaN               NaN
# 1  22                0            NaN                  NaN               NaN
# 2  19                0            NaN                  NaN               NaN
# 3  26                0            NaN                  NaN               NaN
# 4  20                0            NaN                  NaN               NaN
# 5  34                0            NaN                  NaN               NaN
# 6  23                0            NaN                  NaN               NaN
# 7  35                0            NaN                  NaN               NaN
# 8  33                0            NaN                  NaN               NaN
# 9  33                0            NaN                  NaN               NaN
#
#   BootcampMonthsAgo BootcampName BootcampPostSalary BootcampRecommend  \
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc

new_codevs2_pd = dataclean2_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]

new_codevs2_pd.head(10)
# Out:
#   Age AttendedBootcamp BootcampFinish BootcampFullJobAfter BootcampLoanYesNo  \
# 0  28                0            NaN                  NaN               NaN
# 1  22                0            NaN                  NaN               NaN
# 2  19                0            NaN                  NaN               NaN
# 3  26                0            NaN                  NaN               NaN
# 4  20                0            NaN                  NaN               NaN
# 5  34                0            NaN                  NaN               NaN
# 6  23                0            NaN                  NaN               NaN
# 7  35                0            NaN                  NaN               NaN
# 8  33                0            NaN                  NaN               NaN
# 9  33                0            NaN                  NaN               NaN
#
#   BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0                NaN               NaN            NaN
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
yesno = {"0":'No', "1":'Yes'}
new_codevs2_pd.AttendedBootcamp.replace(yesno, inplace=True)
new_codevs2_pd.BootcampFinish.replace(yesno, inplace=True)
new_codevs2_pd.BootcampRecommend.replace(yesno, inplace=True)

new_codevs2_pd.head()

#writer = pd.ExcelWriter('newp2_pdf.xlsx')
#new_codevs2_pd.to_excel(writer,'Sheet1')
#writer.save()
#writer.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#   Age AttendedBootcamp BootcampFinish BootcampFullJobAfter BootcampLoanYesNo  \
# 0  28               No            NaN                  NaN               NaN
# 1  22               No            NaN                  NaN               NaN
# 2  19               No            NaN                  NaN               NaN
# 3  26               No            NaN                  NaN               NaN
# 4  20               No            NaN                  NaN               NaN
#
#   BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0                NaN               NaN            NaN
# 1                NaN               NaN            NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp

BCstay_df = new_codevs2_pd.loc[new_codevs2_pd["AttendedBootcamp"]== "Yes"]
BCstay_df
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32              Yes            Yes                    0
# 97     26              Yes            Yes                    1
# 130    41              Yes            Yes                    1
# 159    26              Yes            Yes                    0
# 188    24              Yes             No                  NaN
# ...    ..              ...            ...                  ...
# 15539  39              Yes            Yes                    1
# 15540  24              Yes            Yes                    1
# 15541  23              Yes            Yes                    1
# 15593  29              Yes             No                  NaN
# 15600  28              Yes            Yes                    1
#
#       BootcampLoanYesNo BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                    0                NaN                No            NaN
# ...

# %%
BCParticpants = pd.DataFrame(dataclean2_df['BootcampName'].value_counts())

#BCParticipants.reset_index(inplace=True)
#BCParticipants.columns = ["BootcampName", "Count"]

#BCParticipants.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea6d146982bf> in <module>
#       1 BCParticpants = pd.DataFrame(dataclean2_df['BootcampName'].value_counts())
#       2
# ----> 3 BCParticipants.reset_index(inplace=True)
#       4 BCParticipants.columns = ["BootcampName", "Count"]
#       5
#
# NameError: name 'BCParticipants' is not defined

# %%
# Create DataFrame of the various boot camps along with the number of participants (enrollees)
# Create a DataFrame from using value_counts

Bootcamps_df = dataclean2_df['BootcampName'].value_counts()
Bootcamps_df
# Out:
# General Assembly         90
# Flatiron School          54
# Dev Bootcamp             48
# The Iron Yard            40
# Prime Digital Academy    30
#                          ..
# World Tech Makers         1
# Operation Spark           1
# Origin Code Academy       1
# Interface Web School      1
# SeedPaths                 1
# Name: BootcampName, Length: 128, dtype: int64

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
Bootcamp_recommend = BCstay_df.loc[BCstay_df['BootcampRecommend']=="Yes",:]
Bootcamp_recommend
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 130    41              Yes            Yes                    1
# 209    25              Yes            Yes                    0
# 272    38              Yes            Yes                    1
# 273    35              Yes            Yes                    1
# 285    23              Yes            Yes                    1
# ...    ..              ...            ...                  ...
# 15436  45              Yes             No                  NaN
# 15465  25              Yes             No                  NaN
# 15539  39              Yes            Yes                    1
# 15541  23              Yes            Yes                    1
# 15600  28              Yes            Yes                    1
#
#       BootcampLoanYesNo BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 130                   1              75000               Yes              3
# ...

# %%
# Merge the two created data frames on the name of tbe bootcamp

# %%
# Calculate percentage of each bootcamp's students who are recommenders
# Think of what should be the numerator and the demoninator

# Sort results in descending order

# Format for percentages

# %%
# Export to excel and remove index
